# %% [markdown]
# ## Reading in the Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
train = pd.read_csv('./datasets/train.csv')

# %%
train.head()
# Out:
#     Id        PID  MS SubClass MS Zoning         Lot Frontage  Lot Area  \
# 0  109  533352170           60        RL                  nan     13517
# 1  544  531379050           60        RL                43.00     11492
# 2  153  535304180           20        RL                68.00      7922
# 3  318  916386060           60        RL                73.00      9802
# 4  255  906425045           50        RL                82.00     14235
#
#   Street Alley Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC  \
# 0   Pave   NaN       IR1          Lvl  ...            0         0     NaN
# 1   Pave   NaN       IR1          Lvl  ...            0         0     NaN
# 2   Pave   NaN       Reg          Lvl  ...            0         0     NaN
# 3   Pave   NaN       Reg          Lvl  ...            0         0     NaN
# 4   Pave   NaN       IR1          Lvl  ...            0         0     NaN
#
#   Fence Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# 0   NaN          NaN        0       3    2010        WD      130500
# 1   NaN          NaN        0       4    2009        WD      220000
# 2   NaN          NaN        0       1    2010        WD      109000
# 3   NaN          NaN        0       4    2010        WD      174000
# 4   NaN          NaN        0       3    2010        WD      138500
#
# [5 rows x 81 columns]

# %%
pd.options.display.float_format = '{:20,.2f}'.format

# %%
train.describe().T
# Out:
#                                count                 mean  \
# Id                          2,051.00             1,474.03
# PID                         2,051.00       713,590,006.09
# MS SubClass                 2,051.00                57.01
# Lot Frontage                1,721.00                69.06
# Lot Area                    2,051.00            10,065.21
# Overall Qual                2,051.00                 6.11
# Overall Cond                2,051.00                 5.56
# Year Built                  2,051.00             1,971.71
# Year Remod/Add              2,051.00             1,984.19
# Mas Vnr Area                2,029.00                99.70
# BsmtFin SF 1                2,050.00               442.30
# BsmtFin SF 2                2,050.00                47.96
# Bsmt Unf SF                 2,050.00               567.73
# Total Bsmt SF               2,050.00             1,057.99
# 1st Flr SF                  2,051.00             1,164.49
# 2nd Flr SF                  2,051.00               329.33
# Low Qual Fin SF             2,051.00                 5.51
# Gr Liv Area                 2,051.00             1,499.33
# Bsmt Full Bath              2,049.00                 0.43
# Bsmt Half Bath              2,049.00                 0.06
# Full Bath                   2,051.00                 1.58
# Half Bath                   2,051.00                 0.37
# Bedroom AbvGr               2,051.00                 2.84
# Kitchen AbvGr               2,051.00                 1.04
# TotRms AbvGrd               2,051.00                 6.44
# Fireplaces                  2,051.00                 0.59
# Garage Yr Blt               1,937.00             1,978.71
# Garage Cars                 2,050.00                 1.78
# Garage Area                 2,050.00               473.67
# Wood Deck SF                2,051.00                93.83
# Open Porch SF               2,051.00                47.56
# Enclosed Porch              2,051.00                22.57
# 3Ssn Porch                  2,051.00                 2.59
# Screen Porch                2,051.00                16.51
# Pool Area                   2,051.00                 2.40
# Misc Val                    2,051.00                51.57
# Mo Sold                     2,051.00                 6.22
# Yr Sold                     2,051.00             2,007.78
# SalePrice                   2,051.00           181,469.70
#
#                                  std                  min  \
# Id                            843.98                 1.00
# PID                   188,691,837.89       526,301,100.00
# MS SubClass                    42.82                20.00
# Lot Frontage                   23.26                21.00
# Lot Area                    6,742.49             1,300.00
# Overall Qual                    1.43                 1.00
# Overall Cond                    1.10                 1.00
# Year Built                     30.18             1,872.00
# Year Remod/Add                 21.04             1,950.00
# Mas Vnr Area                  174.96                 0.00
# BsmtFin SF 1                  461.20                 0.00
# BsmtFin SF 2                  165.00                 0.00
# Bsmt Unf SF                   444.95                 0.00
# Total Bsmt SF                 449.41                 0.00
# 1st Flr SF                    396.45               334.00
# 2nd Flr SF                    425.67                 0.00
# Low Qual Fin SF                51.07                 0.00
# Gr Liv Area                   500.45               334.00
# Bsmt Full Bath                  0.52                 0.00
# Bsmt Half Bath                  0.25                 0.00
# Full Bath                       0.55                 0.00
# Half Bath                       0.50                 0.00
# Bedroom AbvGr                   0.83                 0.00
# Kitchen AbvGr                   0.21                 0.00
# TotRms AbvGrd                   1.56                 2.00
# Fireplaces                      0.64                 0.00
# Garage Yr Blt                  25.44             1,895.00
# Garage Cars                     0.76                 0.00
# Garage Area                   215.93                 0.00
# Wood Deck SF                  128.55                 0.00
# Open Porch SF                  66.75                 0.00
# Enclosed Porch                 59.85                 0.00
# 3Ssn Porch                     25.23                 0.00
# Screen Porch                   57.37                 0.00
# Pool Area                      37.78                 0.00
# Misc Val                      573.39                 0.00
# Mo Sold                         2.74                 1.00
# Yr Sold                         1.31             2,006.00
# SalePrice                  79,258.66            12,789.00
#
#                                  25%                  50%  \
# Id                            753.50             1,486.00
# PID                   528,458,140.00       535,453,200.00
# MS SubClass                    20.00                50.00
# Lot Frontage                   58.00                68.00
# Lot Area                    7,500.00             9,430.00
# Overall Qual                    5.00                 6.00
# Overall Cond                    5.00                 5.00
# Year Built                  1,953.50             1,974.00
# Year Remod/Add              1,964.50             1,993.00
# Mas Vnr Area                    0.00                 0.00
# BsmtFin SF 1                    0.00               368.00
# BsmtFin SF 2                    0.00                 0.00
# Bsmt Unf SF                   220.00               474.50
# Total Bsmt SF                 793.00               994.50
# 1st Flr SF                    879.50             1,093.00
# 2nd Flr SF                      0.00                 0.00
# Low Qual Fin SF                 0.00                 0.00
# Gr Liv Area                 1,129.00             1,444.00
# Bsmt Full Bath                  0.00                 0.00
# Bsmt Half Bath                  0.00                 0.00
# Full Bath                       1.00                 2.00
# Half Bath                       0.00                 0.00
# Bedroom AbvGr                   2.00                 3.00
# Kitchen AbvGr                   1.00                 1.00
# TotRms AbvGrd                   5.00                 6.00
# Fireplaces                      0.00                 1.00
# Garage Yr Blt               1,961.00             1,980.00
# Garage Cars                     1.00                 2.00
# Garage Area                   319.00               480.00
# Wood Deck SF                    0.00                 0.00
# Open Porch SF                   0.00                27.00
# Enclosed Porch                  0.00                 0.00
# 3Ssn Porch                      0.00                 0.00
# Screen Porch                    0.00                 0.00
# Pool Area                       0.00                 0.00
# Misc Val                        0.00                 0.00
# Mo Sold                         4.00                 6.00
# Yr Sold                     2,007.00             2,008.00
# SalePrice                 129,825.00           162,500.00
#
#                                  75%                  max
# Id                          2,198.00             2,930.00
# PID                   907,180,080.00       924,152,030.00
# MS SubClass                    70.00               190.00
# Lot Frontage                   80.00               313.00
# Lot Area                   11,513.50           159,000.00
# Overall Qual                    7.00                10.00
# Overall Cond                    6.00                 9.00
# Year Built                  2,001.00             2,010.00
# Year Remod/Add              2,004.00             2,010.00
# Mas Vnr Area                  161.00             1,600.00
# BsmtFin SF 1                  733.75             5,644.00
# BsmtFin SF 2                    0.00             1,474.00
# Bsmt Unf SF                   811.00             2,336.00
# Total Bsmt SF               1,318.75             6,110.00
# 1st Flr SF                  1,405.00             5,095.00
# 2nd Flr SF                    692.50             1,862.00
# Low Qual Fin SF                 0.00             1,064.00
# Gr Liv Area                 1,728.50             5,642.00
# Bsmt Full Bath                  1.00                 3.00
# Bsmt Half Bath                  0.00                 2.00
# Full Bath                       2.00                 4.00
# Half Bath                       1.00                 2.00
# Bedroom AbvGr                   3.00                 8.00
# Kitchen AbvGr                   1.00                 3.00
# TotRms AbvGrd                   7.00                15.00
# Fireplaces                      1.00                 4.00
# Garage Yr Blt               2,002.00             2,207.00
# Garage Cars                     2.00                 5.00
# Garage Area                   576.00             1,418.00
# Wood Deck SF                  168.00             1,424.00
# Open Porch SF                  70.00               547.00
# Enclosed Porch                  0.00               432.00
# 3Ssn Porch                      0.00               508.00
# Screen Porch                    0.00               490.00
# Pool Area                       0.00               800.00
# Misc Val                        0.00            17,000.00
# Mo Sold                         8.00                12.00
# Yr Sold                     2,009.00             2,010.00
# SalePrice                 214,000.00           611,657.00

# %% [markdown]
# ## EDA

# %%
train.dtypes
# Out:
# Id                  int64
# PID                 int64
# MS SubClass         int64
# MS Zoning          object
# Lot Frontage      float64
# Lot Area            int64
# Street             object
# Alley              object
# Lot Shape          object
# Land Contour       object
# Utilities          object
# Lot Config         object
# Land Slope         object
# Neighborhood       object
# Condition 1        object
# Condition 2        object
# Bldg Type          object
# House Style        object
# Overall Qual        int64
# Overall Cond        int64
# Year Built          int64
# Year Remod/Add      int64
# Roof Style         object
# Roof Matl          object
# Exterior 1st       object
# Exterior 2nd       object
# Mas Vnr Type       object
# Mas Vnr Area      float64
# Exter Qual         object
# Exter Cond         object
#                    ...
# Half Bath           int64
# Bedroom AbvGr       int64
# Kitchen AbvGr       int64
# Kitchen Qual       object
# TotRms AbvGrd       int64
# Functional         object
# Fireplaces          int64
# Fireplace Qu       object
# Garage Type        object
# Garage Yr Blt     float64
# Garage Finish      object
# Garage Cars       float64
# Garage Area       float64
# Garage Qual        object
# Garage Cond        object
# Paved Drive        object
# Wood Deck SF        int64
# Open Porch SF       int64
# Enclosed Porch      int64
# 3Ssn Porch          int64
# Screen Porch        int64
# Pool Area           int64
# Pool QC            object
# Fence              object
# Misc Feature       object
# Misc Val            int64
# Mo Sold             int64
# Yr Sold             int64
# Sale Type          object
# SalePrice           int64
# Length: 81, dtype: object

# %%
train.shape
# Out:
# (2051, 81)

# %%
train.isnull().sum()
# Out:
# Id                   0
# PID                  0
# MS SubClass          0
# MS Zoning            0
# Lot Frontage       330
# Lot Area             0
# Street               0
# Alley             1911
# Lot Shape            0
# Land Contour         0
# Utilities            0
# Lot Config           0
# Land Slope           0
# Neighborhood         0
# Condition 1          0
# Condition 2          0
# Bldg Type            0
# House Style          0
# Overall Qual         0
# Overall Cond         0
# Year Built           0
# Year Remod/Add       0
# Roof Style           0
# Roof Matl            0
# Exterior 1st         0
# Exterior 2nd         0
# Mas Vnr Type        22
# Mas Vnr Area        22
# Exter Qual           0
# Exter Cond           0
#                   ...
# Half Bath            0
# Bedroom AbvGr        0
# Kitchen AbvGr        0
# Kitchen Qual         0
# TotRms AbvGrd        0
# Functional           0
# Fireplaces           0
# Fireplace Qu      1000
# Garage Type        113
# Garage Yr Blt      114
# Garage Finish      114
# Garage Cars          1
# Garage Area          1
# Garage Qual        114
# Garage Cond        114
# Paved Drive          0
# Wood Deck SF         0
# Open Porch SF        0
# Enclosed Porch       0
# 3Ssn Porch           0
# Screen Porch         0
# Pool Area            0
# Pool QC           2042
# Fence             1651
# Misc Feature      1986
# Misc Val             0
# Mo Sold              0
# Yr Sold              0
# Sale Type            0
# SalePrice            0
# Length: 81, dtype: int64

# %% [markdown]
# # A
#
# dropping null values in Lot Frontage

# %%
train['Lot Frontage'].dropna(inplace = True)

# %%
train['Lot Frontage'].dtypes
# Out:
# dtype('float64')
